# %%
pip install selenium

# %%
handle = '' #인스타그램 아이디
pwd = ''  #인스타그램 비밀번호
keyword= '여행'   #검색할 키워드
num_of_pages = 10 #몇 번 스크롤 할 건지; e.g. 200 --> 1730개 게시글 긁어짐

# %%
#함수 정의
from selenium import webdriver
from urllib.parse import quote
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd 
import re

#URL 가져오기
def InstagramUrlFromKeyword (browser,keyword,num_of_pagedowns):
    keyword_url_encode=quote(keyword)
    url='https://www.instagram.com/explore/tags/'+keyword+'/?hl=ko'
    browser.get(url)
    time.sleep(3)
    login = browser.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/span/a[1]/button')
    login.click()
    time.sleep(3)
    user_id = browser.find_element_by_class_name('_2hvTZ.pexuQ.zyHYP')
    pw = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[3]/div/label/input')
    user_id.send_keys(handle)
    pw.send_keys(pwd)
    button = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[4]/button')
    button.click()
    time.sleep(3)
    arr_href=[]
    body=browser.find_element_by_tag_name('body')
    for i in range(num_of_pagedowns):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        post=browser.find_elements_by_class_name('v1Nh3')
        for j in post:
            href_str=j.find_element_by_css_selector('a').get_attribute('href')
            arr_href.append(href_str)
    return set(arr_href)    

char = r'#[\d\w]+'
char2 = re.compile('[^ 0-9a-zA-Zㄱ-ㅣ가-힣!#?]')

#URL에서 데이터 가져오기
def IdHashTagFromInstagram(browser,url):
    browser.get(url)
    datetime = browser.find_element_by_class_name('_1o9PC.Nzb55').get_attribute('title')
    href=browser.find_elements_by_class_name('C4VMK')
    #포스트 내용(글, 태그)
    total_hash_text=[]    
    for i in range(0, len(href)):
        hash_text= href[i].find_element_by_css_selector('span').text
        total_hash_text.append(hash_text)
    tags = re.findall(char, char2.sub(' ',str(total_hash_text)))
    user_name = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/header/div[2]/div[1]/div[1]/h2/a').text
    like_count = int(browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/div[2]/section[2]/div/div/button/span').text)
    
    return datetime, user_name, like_count, tags

# %%
#크롤링
browser= webdriver.Chrome()
arr=InstagramUrlFromKeyword(browser,keyword,num_of_pages)
insta_df=pd.DataFrame(columns = {'Datetime', 'User_Name', 'Like_Count', 'Tags'})

for url in arr:
        try:
            datetime, user_name, like_count, tags = IdHashTagFromInstagram(browser,url)
            insta_df = insta_df.append({'Datetime': datetime, 'User_Name':user_name, 'Like_Count':like_count,'Tags': tags}, ignore_index = True)
        except:
            continue

# %%
insta_df
# Out:
#    Like_Count                                               Tags  \
# 0          39                                                 []
# 1          14  [#성수, #스피닝울프성수, #재즈바, #명당자리, #2019마무리, #고생했엉, ...
# 46  2019년 12월 27일                 _chobu_
# 47  2019년 12월 27일            serahong0514
# 48  2019년 12월 26일             sihun_dream
# 49   2019년 8월 23일              chan_ology
# 50  2019년 12월 26일               like_zer0
# 51   2019년 7월 27일              soominnnnn
# 52  2019년 12월 27일                miinchic
# 53  2019년 12월 27일                p_dinggg
# 54  2019년 12월 27일              blossomsys
# 55  2019년 12월 27일            sosouniquee_
# 56  2019년 12월 26일                  mum_iu
# 57   2019년 8월 21일              chan_ology
# 58  2019년 12월 27일               gratia_s2

# %%
from collections import Counter

# %%
insta_str = []
for tags in insta_df['Tags']:
    insta_str.extend(tags)

# %%
insta_str
# Out:
# ['#성수',
#  '#스피닝울프성수',
#  '#재즈바',
#  '#명당자리',
#  '#2019마무리',
#  '#고생했엉',
#  '#오랜만에좋은사람들과',
#  '#서울',
#  '#서울여행',
#  '#사울카페',
#  '#성수',
#  '#성수동카페',
#  '#성수카페',
#  '#성수아모레',
#  '#카페스타그램',
#  '#옷스타그램',
#  '#아모레성수',
#  '#성수',
#  '#윤경양식당',
#  '#맛있오',
#  '#양이짝아',
#  '#고생해쪄성으니',
#  '#연구원',
#  '#가운',
#  '#10년차',
#  '#직장인',
#  '#요가강사',
#  '#yogainstructor',
#  '#서울숲',
#  '#서울숲요가',
#  '#뚝섬역',
#  '#뚝섬역요가',
#  '#성수',
#  '#성수동요가',
#  '#운동녀',
#  '#운동하는여자',
#  '#요가하는여자',
#  '#하타요가',
#  '#yoga',
#  '#yogini',
#  '#appleiphonexs',
#  '#어린이대공원',
#  '#어린이대공원출사',
#  '#성수',
#  '#성수동',
#  '#성수동카페',
#  '#카페',
#  '#카페출사',
#  '#출사',
#  '#자연',
#  '#식물',
#  '#인물',
#  '#스냅',
#  '#감성',
#  '#디카',
#  '#폰카',
#  '#카메라',
#  '#아이폰',
#  '#풍경',
#  '#갬성',
#  '#가을',
#  '#사진',
#  '#사진그램',
#  '#snap',
#  '#snapshot',
#  '#photography',
#  '#카페봇',
#  '#서울카페',
#  '#커피',
#  '#커피스타그램',
#  '#카페',
#  '#카페스타그램',
#  '#서울',
#  '#성수',
#  '#성수동',
#  '#성수동카페',
#  '#특별한순간2019',
#  '#seoulcafe',
#  '#seoul',
#  '#seoulkorea',
#  '#seongsu',
#  '#seongsudongcafe',
#  '#cafebot',
#  '#coffeestagram',
#  '#cafestagram',
#  '#annygraph',
#  '#달고나',
#  '#차a',
#  '#성수',
#  '#달고나밀크',
#  '#달고나오롱차밀크티',
#  '#달고나스콘',
#  '#이세상의단맛을위하여',
#  '#삼미회',
#  '#일상',
#  '#dalgona',
#  '#milktea',
#  '#tea',
#  '#sweet',
#  '#sosweet',
#  '#scone',
#  '#food',
#  '#dessert',
#  '#daily',
#  '#후식은김치찌개',
#  '#margiela',
#  '#크리스마스파티',
#  '#우리집',
#  '#따뜻한하루',
#  '#모두감사',
#  '#thankyouforcoming',
#  '#2019년',
#  '#크리스마스',
#  '#마니또',
#  '#성수',
#  '#보람',
#  '#지현',
#  '#라희',
#  '#크리스마스칼라',
#  '#그린',
#  '#레드',
#  '#골드',
#  '#드레스코드',
#  '#해피',
#  '#음식',
#  '#케이터링',
#  '#김밥',
#  '#파스타',
#  '#스프링롤',
#  '#치킨',
#  '#애피타이저',
#  '#과일',
#  '#배터짐',
#  '#성수카페',
#  '#크리스마스',
#  '#연말',
#  '#비커즈',
#  '#박성수',
#  '#성수',
#  '#김태유',
#  '#태유',
#  '#홍대',
#  '#버스킹',
#  '#191225',
#  '#selfie',
#  '#daily',
#  '#ootd',
#  '#cafe',
#  '#성수',
#  '#성수카페',
#  '#출근',
#  '#벌써금요일',
#  '#렌트카',
#  '#수입차렌트',
#  '#보험수리',
#  '#사고대차',
#  '#1급공업사',
#  '#수입차전문',
#  '#벤츠',
#  '#BMW',
#  '#볼보',
#  '#재규어',
#  '#포르쉐',
#  '#레인지로버',
#  '#랜드로버',
#  '#폭스바겐',
#  '#전차종보유',
#  '#서울',
#  '#경기',
#  '#전지역',
#  '#강남',
#  '#역삼동',
#  '#압구정동',
#  '#신사동',
#  '#서초동',
#  '#성수',
#  '#성수동',
#  '#5to7',
#  '#과일수플레',
#  '#패션후르츠에이드',
#  '#뚝떡',
#  '#치즈김말이떡볶음',
#  '#알곱창',
#  '#서울숲',
#  '#성수',
#  '#성수동',
#  '#서울숲맛집',
#  '#성수동맛집',
#  '#먹스타그램',
#  '#맛스타그램',
#  '#먹방',
#  '#일상',
#  '#좋아요반사',
#  '#좋반',
#  '#맞팔',
#  '#소통',
#  '#셀피',
#  '#daily',
#  '#dailyfoodfeed',
#  '#foodporn',
#  '#ootd',
#  '#likeforlikes',
#  '#follow',
#  '#l4l',
#  '#f4f',
#  '#2019',
#  '#성수',
#  '#스타우트',
#  '#광주',
#  '#상무지구',
#  '#양림동',
#  '#불로동',
#  '#이태원',
#  '#연남동',
#  '#홍대',
#  '#건대',
#  '#서울',
#  '#가로수길',
#  '#송리단길',
#  '#해리단길',
#  '#성수',
#  '#광주카페',
#  '#서면',
#  '#얼스타그램',
#  '#셀스타그램',
#  '#데일리룩',
#  '#데일리',
#  '#오오티디',
#  '#셀끼꾼',
#  '#좋반',
#  '#좋아요반사',
#  '#선팔하면맞팔',
#  '#선팔맞팔',
#  '#daily',
#  '#instagood',
#  '#instalike',
#  '#likeforlikes',
#  '#성수동',
#  '#텐동',
#  '#맛집',
#  '#튀김',
#  '#덴뿌라',
#  '#성수',
#  '#성수맛집',
#  '#할아버지공장',
#  '#플라워에이드',
#  '#selfie',
#  '#selca',
#  '#selstagram',
#  '#daily',
#  '#dailylook',
#  '#셀카',
#  '#셀스타그램',
#  '#셀피',
#  '#셀카그램',
#  '#성수동카페',
#  '#성수',
#  '#성수',
#  '#댕댕이',
#  '#새끼강아지',
#  '#이마트',
#  '#성수',
#  '#성수동',
#  '#강남',
#  '#한강나들이',
#  '#뚝섬',
#  '#성수동카페',
#  '#바다',
#  '#일상',
#  '#해운대',
#  '#단풍',
#  '#서울',
#  '#여행',
#  '#성수동맛집',
#  '#건대',
#  '#먹스타그램',
#  '#사랑',
#  '#고마워요',
#  '#일상',
#  '#일상그램',
#  '#좋아요',
#  '#좋아요반사',
#  '#홍대',
#  '#오오티디룩',
#  '#오오티디',
#  '#맞팔',
#  '#선팔',
#  '#맞팔하면선팔',
#  '#성수',
#  '#카페',
#  '#cafebot',
#  '#심미안',
#  '#성수동',
#  '#vintage',
#  '#빈티지샵',
#  '#성수동심미안',
#  '#핸드메이드샵',
#  '#편집샵',
#  '#스너퍼',
#  '#양초',
#  '#캔들',
#  '#엔틱',
#  '#엔틱소품',
#  '#싱글라이프',
#  '#성수',
#  '#성수동편집샵',
#  '#simmian',
#  '#성수',
#  '#성수동카페',
#  '#오르에르',
#  '#orerarchive',
#  '#크리스마스이브',
#  '#식사를합시다',
#  '#짜글이',
#  '#만들기',
#  '#짜글짜글',
#  '#맛있네',
#  '#서울숲',
#  '#뚝섬',
#  '#성수',
#  '#성수동',
#  '#뚝섬역',
#  '#맛집',
#  '#음식',
#  '#쌍둥이',
#  '#일상스타그램',
#  '#음식스타그램',
#  '#먹스타그램',
#  '#비밀더비스트로',
#  '#성수',
#  '#서울숲',
#  '#뭐',
#  '#각진거좋아함',
#  '#단단함',
#  '#테이블',
#  '#인테리어',
#  '#인테리어스타그램',
#  '#인테리어소품',
#  '#인테리어데코',
#  '#인테리어그램',
#  '#관심사',
#  '#성수',
#  '#오설록',
#  '#appleiphonexs',
#  '#어린이대공원',
#  '#어린이대공원출사',
#  '#성수',
#  '#성수동',
#  '#성수동카페',
#  '#카페',
#  '#카페출사',
#  '#출사',
#  '#자연',
#  '#식물',
#  '#인물',
#  '#스냅',
#  '#감성',
#  '#디카',
#  '#폰카',
#  '#카메라',
#  '#아이폰',
#  '#풍경',
#  '#갬성',
#  '#가을',
#  '#사진',
#  '#사진그램',
#  '#snap',
#  '#snapshot',
#  '#photography',
#  '#성수',
#  '#성수다락',
#  '#성수어니언',
#  '#데이트',
#  '#럽스타그램',
#  '#instagood',
#  '#instagram',
#  '#daily',
#  '#광주',
#  '#상무지구',
#  '#양림동',
#  '#불로동',
#  '#이태원',
#  '#연남동',
#  '#홍대',
#  '#건대',
#  '#서울',
#  '#가로수길',
#  '#송리단길',
#  '#해리단길',
#  '#성수',
#  '#광주카페',
#  '#서면',
#  '#얼스타그램',
#  '#셀스타그램',
#  '#데일리룩',
#  '#데일리',
#  '#오오티디',
#  '#셀끼꾼',
#  '#좋반',
#  '#좋아요반사',
#  '#선팔하면맞팔',
#  '#선팔맞팔',
#  '#daily',
#  '#instagood',
#  '#instalike',
#  '#likeforlikes',
#  '#우리가사는온도',
#  '#한남동그집',
#  '#성수',
#  '#추억',
#  '#자주',
#  '#먹던걸로',
#  '#마지막',
#  '#다행',
#  '#새로운',
#  '#친구',
#  '#겟',
#  '#성공하세요',
#  '#rookiestar',
#  '#직원',
#  '#연말party',
#  '#2019bye',
#  '#성수',
#  '#tigerpool',
#  '#행복하당',
#  '#성수',
#  '#건대',
#  '#뚝섬',
#  '#서울숲',
#  '#왕십리',
#  '#강변역',
#  '#강남',
#  '#홍대',
#  '#동대문',
#  '#동서울',
#  '#선릉',
#  '#삼성역',
#  '#주말',
#  '#부천',
#  '#낙성대',
#  '#서울대입구',
#  '#패션',
#  '#영화',
#  '#겨울왕국',
#  '#겨울왕국2',
#  '#인스타',
#  '#단발머리스타일',
#  '#insta',
#  '#instadaily',
#  '#pilatesinstructor',
#  '#pilates',
#  '#김또',
#  '#likeforfollow',
#  '#ootdfashion',
#  '#개미룩',
#  '#운동복',
#  '#f',
#  '#선팔맞팔',
#  '#dm',
#  '#다렉',
#  '#좋반',
#  '#반사',
#  '#신천',
#  '#성수',
#  '#강남',
#  '#건대',
#  '#구리',
#  '#잠실나루',
#  '#리안헤어잠실나루점',
#  '#컬러맛집',
#  '#가슴운동',
#  '#chest',
#  '#chestworkout',
#  '#팬톤',
#  '#뮤지엄오브컬러',
#  '#성수',
#  '#아이와가볼만한곳',
#  '#7세',
#  '#예비초등',
#  '#겨울방학',
#  '#에스팩토리',
#  '#museumofcolors',
#  '#크리스티나마키바',
#  '#윤새롬',
#  '#린더글라스',
#  '#아트놈',
#  '#애너토룬',
#  '#올해의컬러',
#  '#셀루리안블루',
#  '#클래식블루',
#  '#그래픽디자인',
#  '#먼셀컬러트리',
#  '#3d프린팅컬러큐브',
#  '#뮤지엄',
#  '#컬러시티',
#  '#베베베베',
#  '#모스크양식',
#  '#안나홈',
#  '#팬톤컬러설명서',
#  '#팬톤컬러연구소',
#  '#컬러블록',
#  '#classicblue',
#  '#메리크리스마스',
#  '#서울숲',
#  '#성수',
#  '#성수동',
#  '#성수동카페거리',
#  '#일상',
#  '#전신샷',
#  '#셀피',
#  '#좋아요반사',
#  '#좋반',
#  '#맞팔',
#  '#일친',
#  '#merrychristmas',
#  '#daily',
#  '#ootd',
#  '#dailylook',
#  '#selfies',
#  '#likeforlikes',
#  '#likeforfollow',
#  '#l4l',
#  '#f4f',
#  '#트렌드코리아2020',
#  '#트코이벤트',
#  '#트코인증',
#  '#미래의창',
#  '#게시물이1000개가넘네',
#  '#소비트렌드',
#  '#컨셉을연출하라',
#  '#김난도교수',
#  '#함께할수있을까',
#  '#이벤트보다',
#  '#미래를향해',
#  '#미래지향적인간',
#  '#카페모임',
#  '#취미활동',
#  '#성수',
#  '#성수카페골목',
#  '#성수연방',
#  '#2층책방',
#  '#성수',
#  '#카페',
#  '#우디집',
#  '#꿀단지',
#  '#테린느',
#  '#appleiphonexs',
#  '#어린이대공원',
#  '#어린이대공원출사',
#  '#성수',
#  '#성수동',
#  '#성수동카페',
#  '#카페',
#  '#카페출사',
#  '#출사',
#  '#자연',
#  '#식물',
#  '#인물',
#  '#스냅',
#  '#감성',
#  '#디카',
#  '#폰카',
#  '#카메라',
#  '#아이폰',
#  '#풍경',
#  '#갬성',
#  '#가을',
#  '#사진',
#  '#사진그램',
#  '#snap',
#  '#snapshot',
#  '#photography',
#  '#selfie',
#  '#likeforlikes',
#  '#shopping',
#  '#followforfollowback',
#  '#instagood',
#  '#instagram',
#  '#daily',
#  '#dailylook',
#  '#ootd',
#  '#seoul',
#  '#fashion',
#  '#instalike',
#  '#korea',
#  '#coffee',
#  '#달고나라떼',
#  '#카페',
#  '#서울',
#  '#성수',
#  '#성수동',
#  '#강남',
#  '#ㅊa',
#  '#다이렉트',
#  '#소통',
#  '#좋아요',
#  '#좋튀',
#  '#좋반',
#  '#옷스타그램',
#  '#맞팔',
#  '#선팔',
#  '#00',
#  '#미디어계의바울',
#  '#요가천사',
#  '#크리스찬배우',
#  '#스타일리쉬끝판왕목사님',
#  '#어린예쁜가혜',
#  '#나이키행사아님',
#  '#감사합니다',
#  '#사랑합니다',
#  '#주님']

# %%
c = Counter(insta_str)

# %%
c.most_common(50)
# Out:
# [('#성수', 37),
#  ('#성수동', 12),
#  ('#daily', 9),
#  ('#성수동카페', 8),
#  ('#서울', 7),
#  ('#카페', 7),
#  ('#서울숲', 6),
#  ('#좋반', 6),
#  ('#일상', 5),
#  ('#홍대', 5),
#  ('#강남', 5),
#  ('#좋아요반사', 5),
#  ('#likeforlikes', 5),
#  ('#건대', 5),
#  ('#ootd', 4),
#  ('#맞팔', 4),
#  ('#instagood', 4),
#  ('#성수카페', 3),
#  ('#appleiphonexs', 3),
#  ('#어린이대공원', 3),
#  ('#어린이대공원출사', 3),
#  ('#카페출사', 3),
#  ('#출사', 3),
#  ('#자연', 3),
#  ('#식물', 3),
#  ('#인물', 3),
#  ('#스냅', 3),
#  ('#감성', 3),
#  ('#디카', 3),
#  ('#폰카', 3),
#  ('#카메라', 3),
#  ('#아이폰', 3),
#  ('#풍경', 3),
#  ('#갬성', 3),
#  ('#가을', 3),
#  ('#사진', 3),
#  ('#사진그램', 3),
#  ('#snap', 3),
#  ('#snapshot', 3),
#  ('#photography', 3),
#  ('#selfie', 3),
#  ('#먹스타그램', 3),
#  ('#셀피', 3),
#  ('#셀스타그램', 3),
#  ('#오오티디', 3),
#  ('#선팔맞팔', 3),
#  ('#instalike', 3),
#  ('#dailylook', 3),
#  ('#뚝섬', 3),
#  ('#카페스타그램', 2)]

# %%
insta_df.to_csv(keyword + '.csv',mode='w', encoding='euc-kr')
