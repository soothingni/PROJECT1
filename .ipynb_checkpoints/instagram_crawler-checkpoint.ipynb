# %%
pip install selenium

# %%
handle = 'sunnydopia@live.co.kr' #인스타그램 아이디
pwd = '*helloimys90'  #인스타그램 비밀번호
keyword= '치즈케이크'   #검색할 키워드
num_of_pages = 1000 #몇 번 스크롤 할 건지; e.g. 200 --> 1730개 게시글 긁어짐

# %%
#함수 정의
from selenium import webdriver
from urllib.parse import quote
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd 
import re

#URL 가져오기
def InstagramUrlFromKeyword (browser,keyword,num_of_pagedowns):
    keyword_url_encode=quote(keyword)
    url='https://www.instagram.com/explore/tags/'+keyword+'/?hl=ko'
    browser.get(url)
    time.sleep(3)
    login = browser.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/span/a[1]/button')
    login.click()
    time.sleep(3)
    user_id = browser.find_element_by_class_name('_2hvTZ.pexuQ.zyHYP')
    pw = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[3]/div/label/input')
    user_id.send_keys(handle)
    pw.send_keys(pwd)
    button = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[4]/button')
    button.click()
    time.sleep(3)
    arr_href=[]
    body=browser.find_element_by_tag_name('body')
    for i in range(num_of_pagedowns):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        post=browser.find_elements_by_class_name('v1Nh3')
        for j in post:
            href_str=j.find_element_by_css_selector('a').get_attribute('href')
            arr_href.append(href_str)
    return set(arr_href)    

char = r'#[\d\w]+'
char2 = re.compile('[^ 0-9a-zA-Zㄱ-ㅣ가-힣!#?]')

#URL에서 데이터 가져오기
def IdHashTagFromInstagram(browser,url):
    browser.get(url)
    datetime = browser.find_element_by_class_name('_1o9PC.Nzb55').get_attribute('title')
    href=browser.find_elements_by_class_name('C4VMK')
    #포스트 내용(글, 태그)
    total_hash_text=[]    
    for i in range(0, len(href)):
        hash_text= href[i].find_element_by_css_selector('span').text
        total_hash_text.append(hash_text)
    tags = re.findall(char, char2.sub(' ',str(total_hash_text)))
    user_name = browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/header/div[2]/div[1]/div[1]/h2/a').text
    like_count = int(browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/article/div[2]/section[2]/div/div/button/span').text)
    location = browser.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/header/div[2]/div[2]/div[2]/a').text
    return datetime, user_name, like_count, tags, location

# %%
#크롤링
browser= webdriver.Chrome()
arr=InstagramUrlFromKeyword(browser, keyword, num_of_pages)
insta_df=pd.DataFrame(columns = {'Datetime', 'User_Name', 'Like_Count', 'Tags', 'Location'})

for url in arr:
        try:
            datetime, user_name, like_count, tags, location = IdHashTagFromInstagram(browser,url)
            insta_df = insta_df.append({'Datetime': datetime, 'User_Name':user_name, 'Like_Count':like_count,'Tags': tags, 'Location' : location}, ignore_index = True)
        except:
            continue

# %%
len(arr)
# Out:
# 7776

# %%
insta_df
# Out:
#      Like_Count       Datetime  \
# 0            17  2019년 12월 25일
# 1            53   2019년 12월 2일
# 2            20  2019년 10월 23일
# 3            44  2019년 12월 16일
# 4            23   2019년 12월 3일
# ...         ...            ...
# 1603        885   2019년 8월 21일
# 1604         41  2019년 12월 11일
# 1605         13   2019년 12월 5일
# 1606        784   2019년 12월 3일
# 1607          2  2019년 10월 20일
#
#                                                    Tags  \
# 0     [#업소용중고주방, #업고용중고주방용품, #업소용주방기구, #업소용주방용품쇼핑몰, ...
# 1     [#카페투어, #맛집투어, #카페맛집, #논현카페, #논현맛집, #선릉카페, #선릉...
# 2     [#강남맛집, #강남마카롱, #대치동맛집, #대치동마카롱, #강남뚱카롱, #역삼마카...
# 3     [#피슈마라홍탕서울시청점, #피슈마라홍탕, #무교동맛집, #무교로14, #샹궈, #...
# 4     [#이도, #역삼이자카야, #엘지아트센터맛집, #강남구, #역삼이도, #역삼맛집, ...
# ...                                                 ...
# 1603                          [#익선동맛집, #익선동데이트, #익선동카페]
# 1604  [#linetattoo, #ornamenttattoo, #tattoo, #handp...
# 1605  [#포스코센터, #크리스마스, #미리크리스마스, #메리크리스마스, #포스코사거리맛집...
# 1606  [#로또당첨, #로또1등, #로또당첨번호, #로또, #로또리치, #로또당첨, #로또...
# 1607  [#셔츠룸, #강남셔츠룸, #강남가라오케, #가라오케, #강남유흥, #유흥, #유앤...
#
#                            User_Name
# 0                  ds_aircon_kitchen
# 1                       nana_____kkk
# 2                       palweol_cafe
# 3     pixiumalahongtangseoulcityhall
# 4                            woska77
# ...                              ...
# 1603                     seoul.woman
# 1604                       jeii_poke
# 1605                   shybana_posco
# 1606                         monoeet
# 1607                          681.1a
#
# [1608 rows x 4 columns]

# %%
#csv 저장
insta_df.to_csv(keyword + '.csv',mode='w', encoding='euc-kr')

# %%
#빈도분석
from collections import Counter

insta_str = []
for tags in insta_df['Tags']:
    insta_str.extend(tags)
    
c = Counter(insta_str)

c.most_common()
# Out:
# [('#선릉맛집', 1472),
#  ('#강남맛집', 465),
#  ('#선릉역맛집', 325),
#  ('#대치동맛집', 256),
#  ('#먹스타그램', 244),
#  ('#맛스타그램', 236),
#  ('#일상', 236),
#  ('#퍼블릭', 197),
#  ('#역삼맛집', 195),
#  ('#선릉', 189),
#  ('#데일리', 182),
#  ('#강남', 150),
#  ('#서울맛집', 144),
#  ('#광안리맛집', 134),
#  ('#맛집', 133),
#  ('#해운대맛집', 133),
#  ('#소통', 129),
#  ('#맞팔', 122),
#  ('#회식', 118),
#  ('#삼성동맛집', 117),
#  ('#f4f', 105),
#  ('#모임', 102),
#  ('#서면맛집', 101),
#  ('#가라오케', 100),
#  ('#접대', 100),
#  ('#강남가라오케', 99),
#  ('#강남셔츠룸', 98),
#  ('#강남유흥', 98),
#  ('#유흥', 98),
#  ('#유앤미', 98),
#  ('#런닝레빗', 98),
#  ('#생일파티', 98),
#  ('#밤일', 98),
#  ('#강남란제리', 98),
#  ('#알바', 98),
#  ('#고액알바', 98),
#  ('#단기알바', 98),
#  ('#고소득알바', 98),
#  ('#유흥알바', 98),
#  ('#급전', 98),
#  ('#전포동맛집', 96),
#  ('#먹방', 95),
#  ('#선릉카페', 93),
#  ('#회식장소', 91),
#  ('#민락동맛집', 87),
#  ('#해운대술집', 87),
#  ('#센텀맛집', 87),
#  ('#문정동맛집', 87),
#  ('#미스터스시', 86),
#  ('#광안리술집', 86),
#  ('#남천동맛집', 86),
#  ('#센텀시티맛집', 86),
#  ('#재송동맛집', 86),
#  ('#서면술집', 86),
#  ('#서면밥집', 86),
#  ('#가락동맛집', 86),
#  ('#거제도맛집', 86),
#  ('#거제맛집', 86),
#  ('#괴정동맛집', 86),
#  ('#송파맛집', 86),
#  ('#옥포맛집', 86),
#  ('#디저트', 81),
#  ('#맛집추천', 79),
#  ('#여우알바', 77),
#  ('#셔츠룸', 73),
#  ('#풀싸롱', 73),
#  ('#강남룸', 73),
#  ('#선팔', 71),
#  ('#좋아요', 70),
#  ('#도쿄등심', 69),
#  ('#선릉역', 68),
#  ('#마라탕', 66),
#  ('#청담맛집', 65),
#  ('#daily', 64),
#  ('#foodstagram', 62),
#  ('#선릉마카롱', 59),
#  ('#l4l', 58),
#  ('#선릉역중국집', 57),
#  ('#가로수길맛집', 55),
#  ('#선팔하면맞팔', 55),
#  ('#follow4follow', 54),
#  ('#소고기', 54),
#  ('#마카롱맛집', 54),
#  ('#수성못맛집', 53),
#  ('#삼성맛집', 53),
#  ('#포스코사거리맛집', 51),
#  ('#한우', 51),
#  ('#대치동마카롱', 50),
#  ('#삼성역맛집', 49),
#  ('#selfie', 47),
#  ('#강남마카롱', 46),
#  ('#맛집탐방', 46),
#  ('#크리스마스', 46),
#  ('#콜키지프리', 45),
#  ('#follow', 45),
#  ('#광주맛집', 45),
#  ('#jmt', 45),
#  ('#한티역', 44),
#  ('#달맞이맛집', 44),
#  ('#성수동맛집', 44),
#  ('#좋아요반사', 44),
#  ('#마카롱', 44),
#  ('#논현동맛집', 43),
#  ('#존맛탱', 43),
#  ('#디저트카페', 42),
#  ('#lfl', 42),
#  ('#followme', 42),
#  ('#dessert', 42),
#  ('#한티맛집', 41),
#  ('#위례맛집', 41),
#  ('#한티역맛집', 41),
#  ('#마린시티맛집', 40),
#  ('#JMT', 40),
#  ('#강남성형외과', 39),
#  ('#맞팔가요', 39),
#  ('#instalike', 39),
#  ('#역삼카페', 39),
#  ('#강남카페', 38),
#  ('#선릉회식', 38),
#  ('#fff', 38),
#  ('#카페스타그램', 38),
#  ('#잠실마카롱', 37),
#  ('#대치동', 37),
#  ('#macaron', 36),
#  ('#온천천맛집', 36),
#  ('#tokyosirloin', 36),
#  ('#한우오마카세', 36),
#  ('#스카이라운지', 36),
#  ('#오픈테이블', 36),
#  ('#역삼', 36),
#  ('#instafood', 36),
#  ('#파렐부띠끄', 35),
#  ('#스키야키', 35),
#  ('#선릉맛집추천', 35),
#  ('#코엑스맛집', 35),
#  ('#압구정맛집', 35),
#  ('#선릉디저트', 34),
#  ('#다이닝', 34),
#  ('#선릉점심맛집', 34),
#  ('#기념일', 33),
#  ('#선릉술집', 32),
#  ('#강남연말모임', 32),
#  ('#데이트코스', 32),
#  ('#선릉다이어트', 32),
#  ('#술스타그램', 32),
#  ('#마라차이즈', 32),
#  ('#선릉네일', 32),
#  ('#대치동학원가', 32),
#  ('#고반식당삼성점', 31),
#  ('#신사맛집', 31),
#  ('#커피', 31),
#  ('#연예인맛집', 30),
#  ('#선릉점심', 30),
#  ('#역삼동맛집', 30),
#  ('#마카롱그램', 30),
#  ('#선릉역회식장소', 30),
#  ('#한티마카롱', 29),
#  ('#선릉데이트', 29),
#  ('#좋반', 29),
#  ('#맛집스타그램', 29),
#  ('#마카롱선물', 29),
#  ('#대치맛집', 29),
#  ('#스콘맛집', 29),
#  ('#뚱카롱', 28),
#  ('#강남역맛집', 28),
#  ('#런치맛집', 28),
#  ('#접대장소', 28),
#  ('#팔로우', 28),
#  ('#카페', 27),
#  ('#잠실맛집', 27),
#  ('#김치찌개맛집', 27),
#  ('#삼성동맛집추천', 27),
#  ('#선팔맞팔', 27),
#  ('#강남역', 27),
#  ('#데이트', 27),
#  ('#수제버거', 27),
#  ('#instadaily', 27),
#  ('#잠실카페', 26),
#  ('#서울3대김치찌개', 26),
#  ('#삼성역맛집추천', 26),
#  ('#두루치기맛집', 26),
#  ('#파운드케이크', 26),
#  ('#삼성동밥집', 25),
#  ('#대치동밥집', 25),
#  ('#삼성동점심', 25),
#  ('#마라샹궈', 25),
#  ('#서래향', 25),
#  ('#셀피', 25),
#  ('#수제버거맛집', 25),
#  ('#seoul', 25),
#  ('#스콘', 25),
#  ('#shillastay', 25),
#  ('#논현맛집', 24),
#  ('#삼성역밥집', 24),
#  ('#럽스타그램', 24),
#  ('#셀카', 24),
#  ('#선릉어깨통증', 24),
#  ('#꽃다발', 24),
#  ('#배민', 23),
#  ('#배달', 23),
#  ('#food', 23),
#  ('#다쿠아즈', 23),
#  ('#강남디저트', 23),
#  ('#서울', 23),
#  ('#쿠키', 23),
#  ('#베이커리카페', 23),
#  ('#카페투어', 22),
#  ('#역삼동중국집', 22),
#  ('#빵스타그램', 22),
#  ('#빵', 21),
#  ('#foodie', 21),
#  ('#요기요', 21),
#  ('#도곡동맛집', 21),
#  ('#선릉역카페', 21),
#  ('#선릉이자카야', 21),
#  ('#수제쿠키', 21),
#  ('#와인', 21),
#  ('#일상스타그램', 21),
#  ('#서래향선릉', 21),
#  ('#답례품', 21),
#  ('#빵지순례', 21),
#  ('#얌얌랩', 21),
#  ('#Yummy', 21),
#  ('#맛집투어', 20),
#  ('#쿠팡이츠배달', 20),
#  ('#선릉역중식당', 20),
#  ('#역삼중식당', 20),
#  ('#디저트맛집', 20),
#  ('#점심', 20),
#  ('#선릉역네일', 20),
#  ('#파스타', 20),
#  ('#뇸뇸', 20),
#  ('#입시미술맛집', 20),
#  ('#대치동파란학원', 20),
#  ('#맛집갈랩', 20),
#  ('#맛집얌선생', 20),
#  ('#foodpick', 20),
#  ('#베이커리', 19),
#  ('#케이크', 19),
#  ('#서울송년회장소', 19),
#  ('#강남연말회식', 19),
#  ('#수원맛집', 19),
#  ('#선릉디저트카페', 19),
#  ('#직장인', 19),
#  ('#마카몽', 19),
#  ('#웨딩네일', 19),
#  ('#선릉역회식', 19),
#  ('#쿠팡이츠', 19),
#  ('#배고파', 19),
#  ('#커플데이트', 18),
#  ('#강남네일', 18),
#  ('#푸드스타그램', 18),
#  ('#macarons', 18),
#  ('#마카롱택배', 18),
#  ('#디저트그램', 18),
#  ('#캐릭터마카롱', 18),
#  ('#치찌중화식탁', 18),
#  ('#존맛탱구리', 18),
#  ('#족발맛집', 17),
#  ('#강남송년회장소', 17),
#  ('#삼성', 17),
#  ('#배달의민족', 17),
#  ('#맞팔환영', 17),
#  ('#음식스타그램', 17),
#  ('#coffee', 17),
#  ('#부산맛집', 17),
#  ('#선정릉', 17),
#  ('#대형다발', 17),
#  ('#선정릉맛집', 17),
#  ('#cafe', 17),
#  ('#이스트덜위치', 17),
#  ('#무색소', 16),
#  ('#무색소마카롱', 16),
#  ('#진선여고', 16),
#  ('#좋반환영', 16),
#  ('#먹스타', 16),
#  ('#청담동네일', 16),
#  ('#nail', 16),
#  ('#선릉24시맛집', 16),
#  ('#핫플', 16),
#  ('#불금', 16),
#  ('#cake', 16),
#  ('#지구당', 15),
#  ('#점심메뉴', 15),
#  ('#선릉먹자골목', 15),
#  ('#강남연말회식장소', 15),
#  ('#첫줄', 15),
#  ('#좋아요그램', 15),
#  ('#크리스마스마카롱', 15),
#  ('#선물', 15),
#  ('#곱창', 15),
#  ('#선릉네일샵', 15),
#  ('#네일아트', 15),
#  ('#논현동네일', 15),
#  ('#nailart', 15),
#  ('#nails', 15),
#  ('#가로수길', 15),
#  ('#선릉역마카롱', 15),
#  ('#샹베리', 15),
#  ('#원테이블레스토랑', 15),
#  ('#24시간맛집', 15),
#  ('#크리스마스선물', 15),
#  ('#909버거', 15),
#  ('#역삼신라스테이', 15),
#  ('#poundcake', 15),
#  ('#cookies', 15),
#  ('#혼밥', 14),
#  ('#촬촬1982', 14),
#  ('#존맛', 14),
#  ('#강남송년회', 14),
#  ('#서울망년회장소', 14),
#  ('#송년회', 14),
#  ('#강남배달', 14),
#  ('#샐러드', 14),
#  ('#띵크하다', 14),
#  ('#흑화당선릉점', 14),
#  ('#뽕족', 14),
#  ('#이자카야나무', 14),
#  ('#먹방스타그램', 14),
#  ('#젤네일', 14),
#  ('#압구정젤네일', 14),
#  ('#강남네일샵추천', 14),
#  ('#젤전문', 14),
#  ('#쮸네일', 14),
#  ('#풀스톤네일', 14),
#  ('#신사', 14),
#  ('#신논현맛집', 14),
#  ('#CHAMBERRY', 14),
#  ('#인친', 14),
#  ('#909버거앤파스타', 14),
#  ('#909burger', 14),
#  ('#알고보니파스타맛집', 14),
#  ('#카페파이', 14),
#  ('#수제파이', 14),
#  ('#파이', 14),
#  ('#호두파이', 14),
#  ('#도곡동', 14),
#  ('#강남핫플', 14),
#  ('#커피맛집', 14),
#  ('#선릉더예쁨', 14),
#  ('#한남동맛집', 13),
#  ('#역삼마카롱', 13),
#  ('#학동맛집', 13),
#  ('#혼술', 13),
#  ('#훠궈', 13),
#  ('#인테리어', 13),
#  ('#족발', 13),
#  ('#선릉역디저트', 13),
#  ('#삼성역', 13),
#  ('#이자카야맛집', 13),
#  ('#맞팔100', 13),
#  ('#좋아요테러', 13),
#  ('#좋반테러', 13),
#  ('#l4like', 13),
#  ('#선릉술집추천', 13),
#  ('#인스타푸드', 13),
#  ('#희카롱', 13),
#  ('#수제청', 13),
#  ('#고반식당', 13),
#  ('#선릉역필라테스', 13),
#  ('#삼성동필라테스', 13),
#  ('#pilates', 13),
#  ('#선릉pt', 13),
#  ('#남포동맛집', 13),
#  ('#꽃', 13),
#  ('#꽃스타그램', 13),
#  ('#포장', 13),
#  ('#여우알', 13),
#  ('#카페파이대치점', 13),
#  ('#caffepie', 13),
#  ('#송리단길', 13),
#  ('#홍대맛집', 12),
#  ('#역삼이자카야', 12),
#  ('#마라', 12),
#  ('#연말모임', 12),
#  ('#연어', 12),
#  ('#선릉도시락', 12),
#  ('#선릉커피숍', 12),
#  ('#이자카야나무선릉점', 12),
#  ('#선릉룸술집', 12),
#  ('#이자카야추천', 12),
#  ('#좋아요반사테러', 12),
#  ('#마카롱세트', 12),
#  ('#heecaron', 12),
#  ('#코엑스', 12),
#  ('#배달맛집', 12),
#  ('#선릉회식장소', 12),
#  ('#연말', 12),
#  ('#선릉선물', 12),
#  ('#강남선물', 12),
#  ('#뼈숯불구이', 12),
#  ('#선릉허리디스크', 12),
#  ('#선릉직장인필라테스', 12),
#  ('#선릉척추측만', 12),
#  ('#포스코사거리필라테스', 12),
#  ('#삼성역필라테스', 12),
#  ('#pilateslover', 12),
#  ('#pilatesmovement', 12),
#  ('#pilatesinstructor', 12),
#  ('#rehab', 12),
#  ('#선릉체형교정필라테스', 12),
#  ('#역삼체형교정필라테스', 12),
#  ('#선릉골반교정', 12),
#  ('#선릉운동', 12),
#  ('#역삼다이어트', 12),
#  ('#삼성동체형교정', 12),
#  ('#도곡동필라테스', 12),
#  ('#일원동필라테스', 12),
#  ('#대치동필라테스', 12),
#  ('#뽕나무쟁이', 12),
#  ('#선릉역점심', 12),
#  ('#나를위한꽃집', 12),
#  ('#스노우폭스플라워', 12),
#  ('#프로포즈꽃다발', 12),
#  ('#꽃집일상', 12),
#  ('#꽃바구니', 12),
#  ('#부케', 12),
#  ('#선릉역꽃집', 12),
#  ('#선릉핫플레이스', 12),
#  ('#르네상스호텔', 12),
#  ('#스노우폭스플라워선릉르네상스점', 12),
#  ('#장미다발', 12),
#  ('#선릉르네상스점', 12),
#  ('#snowfoxflowers', 12),
#  ('#instaflower', 12),
#  ('#가성비갑', 12),
#  ('#라떼맛집', 12),
#  ('#경천애인2237', 12),
#  ('#mellower', 12),
#  ('#대치4동', 12),
#  ('#대치동미술학원가', 12),
#  ('#gangnam', 12),
#  ('#선릉왁싱', 12),
#  ('#다이어트', 11),
#  ('#테헤란로맛집', 11),
#  ('#자연눈썹', 11),
#  ('#꼬끄러스크', 11),
#  ('#연애의맛', 11),
#  ('#연애의맛시즌3', 11),
#  ('#연애의맛마카롱', 11),
#  ('#우도맛집', 11),
#  ('#삼성동회식장소', 11),
#  ('#도곡동마카롱', 11),
#  ('#대치동디저트', 11),
#  ('#선릉오뎅바', 11),
#  ('#맛점', 11),
#  ('#속눈썹펌', 11),
#  ('#강남데이트', 11),
#  ('#진로이즈백', 11),
#  ('#샐러드맛집', 11),
#  ('#선릉참치', 11),
#  ('#송리단길맛집', 11),
#  ('#멜로워', 11),
#  ('#선릉카페추천', 11),
#  ('#빵맛집', 11),
#  ('#셀스타그램', 11),
#  ('#양재맛집', 10),
#  ('#강남구', 10),
#  ('#역삼술집', 10),
#  ('#삼성중앙역맛집', 10),
#  ('#foodporn', 10),
#  ('#힙한훠궈집', 10),
#  ('#깨끗한식당', 10),
#  ('#hotpot', 10),
#  ('#촨촨향', 10),
#  ('#훠궈맛집', 10),
#  ('#chineserestaurant', 10),
#  ('#interior', 10),
#  ('#선릉훠궈', 10),
#  ('#퇴근', 10),
#  ('#단체주문', 10),
#  ('#청담', 10),
#  ('#논현', 10),
#  ('#반영구', 10),
#  ('#동문시장야시장', 10),
#  ('#흑화당', 10),
#  ('#강남반영구', 10),
#  ('#수요미식회', 10),
#  ('#안심', 10),
#  ('#모도우', 10),
#  ('#원데이클래스', 10),
#  ('#신동궁감자탕', 10),
#  ('#로로피아나코트', 10),
#  ('#이승재참치', 10),
#  ('#참치맛집', 10),
#  ('#하이볼', 10),
#  ('#서울카페', 10),
#  ('#송리단길카페', 10),
#  ('#멜로워커피', 10),
#  ('#멜로워코리아', 10),
#  ('#역삼카페추천', 10),
#  ('#강남카페추천', 10),
#  ('#인생커피', 10),
#  ('#베이커리투어', 10),
#  ('#금요일', 10),
#  ('#agathabakery', 10),
#  ('#아가다베이커리', 10),
#  ('#파란대문빵집', 10),
#  ('#파운드케이크맛집', 10),
#  ('#파운드맛집', 10),
#  ('#역삼빵집', 10),
#  ('#선릉빵집', 10),
#  ('#아가다라떼', 10),
#  ('#신라스테이', 10),
#  ('#체크네일', 10),
#  ('#음식', 10),
#  ('#강남야식', 10),
#  ('#청담카페', 9),
#  ('#마라탕맛집', 9),
#  ('#꿔바로우', 9),
#  ('#맛있다그램', 9),
#  ('#소통해요', 9),
#  ('#촬촬샹', 9),
#  ('#촨촨', 9),
#  ('#테헤란로', 9),
#  ('#눈썹문신', 9),
#  ('#뽕나무쟁이족발', 9),
#  ('#볶음밥', 9),
#  ('#판교맛집', 9),
#  ('#등심', 9),
#  ('#koreanfood', 9),
#  ('#할로윈마카롱', 9),
#  ('#용무짬뽕', 9),
#  ('#풀스와', 9),
#  ('#역삼2차', 9),
#  ('#선릉2차', 9),
#  ('#역삼오뎅바', 9),
#  ('#역삼꼬치구이', 9),
#  ('#선릉꼬치구이', 9),
#  ('#역삼이자까야', 9),
#  ('#선릉이자까야', 9),
#  ('#참치', 9),
#  ('#먹부림', 9),
#  ('#별미곳간', 9),
#  ('#애터미사업', 9),
#  ('#화병꽂이', 9),
#  ('#핫플레이스', 9),
#  ('#역삼역맛집', 9),
#  ('#강남떡볶이맛집', 9),
#  ('#여의도맛집', 9),
#  ('#moca', 9),
#  ('#mocaseoul', 9),
#  ('#모카런던', 9),
#  ('#mocamoca', 9),
#  ('#런던카페', 9),
#  ('#송파마카롱', 9),
#  ('#송파카페', 9),
#  ('#석촌호수카페', 9),
#  ('#롯데월드몰', 9),
#  ('#잠실롯데월드몰', 9),
#  ('#lotteworld', 9),
#  ('#롯데월드몰맛집', 9),
#  ('#가을네일', 9),
#  ('#고기스타그램', 9),
#  ('#짜장맛집', 9),
#  ('#선릉중국집', 9),
#  ('#도곡맛집', 8),
#  ('#피슈마라홍탕', 8),
#  ('#마라샹궈맛집', 8),
#  ('#훠거', 8),
#  ('#Repost', 8),
#  ('#메이크샐러드선릉', 8),
#  ('#역삼동699', 8),
#  ('#서초', 8),
#  ('#요플', 8),
#  ('#첫줄반사', 8),
#  ('#강남눈썹문신', 8),
#  ('#역삼속눈썹', 8),
#  ('#포스코사거리', 8),
#  ('#야식', 8),
#  ('#소주', 8),
#  ('#직장인점심', 8),
#  ('#여우알바생', 8),
#  ('#삼성역회식장소', 8),
#  ('#대치동카페', 8),
#  ('#용무있습니까', 8),
#  ('#스와로브스키네일', 8),
#  ('#후식', 8),
#  ('#고기', 8),
#  ('#맞팔해요', 8),
#  ('#부산카페', 8),
#  ('#대창', 8),
#  ('#대치', 8),
#  ('#화병', 8),
#  ('#마라테이블', 8),
#  ('#포스코센터', 8),
#  ('#미쓰양꼬치', 8),
#  ('#농민백암순대', 8),
#  ('#경주맛집', 8),
#  ('#버거맛집', 8),
#  ('#예쁜카페', 8),
#  ('#참치회', 8),
#  ('#선릉속눈썹펌', 8),
#  ('#삼성동왁싱', 8),
#  ('#강남왁싱', 8),
#  ('#맛스타', 8),
#  ('#선릉역고기집', 8),
#  ('#운동', 8),
#  ('#짬뽕맛집', 8),
#  ('#인생짬뽕', 8),
#  ('#고기짬뽕', 8),
#  ('#선릉짬뽕', 8),
#  ('#짜장21', 8),
#  ('#탕수육맛집', 8),
#  ('#대치동중국집', 8),
#  ('#서울시청맛집', 7),
#  ('#이도', 7),
#  ('#엘지아트센터맛집', 7),
#  ('#역삼이도', 7),
#  ('#다이어트식단', 7),
#  ('#마라펍앤다이닝', 7),
#  ('#회', 7),
#  ('#대치동집', 7),
#  ('#삼겹살', 7),
#  ('#조개천국', 7),
#  ('#목살샐러드', 7),
#  ('#달맞이고개카페', 7),
#  ('#함덕맛집', 7),
#  ('#서초동맛집', 7),
#  ('#논현동카페', 7),
#  ('#서래마을맛집', 7),
#  ('#에르메스', 7),
#  ('#홍대반영구', 7),
#  ('#순천반영구', 7),
#  ('#샤로수길맛집', 7),
#  ('#선릉속눈썹', 7),
#  ('#맛집그램', 7),
#  ('#꿀맛', 7),
#  ('#foodpic', 7),
#  ('#곱창전골', 7),
#  ('#물금맛집', 7),
#  ('#삼성동', 7),
#  ('#신촌맛집', 7),
#  ('#이대맛집', 7),
#  ('#타코', 7),
#  ('#저녁', 7),
#  ('#dacquoise', 7),
#  ('#선릉다쿠아즈', 7),
#  ('#스시', 7),
#  ('#디자인마카롱', 7),
#  ('#뼈찜', 7),
#  ('#서울애터미', 7),
#  ('#경기도애터미', 7),
#  ('#안양맛집', 7),
#  ('#의왕맛집', 7),
#  ('#안양카페', 7),
#  ('#수원카페', 7),
#  ('#의왕카페', 7),
#  ('#안양일번가맛집', 7),
#  ('#수성못카페', 7),
#  ('#샤넬코트', 7),
#  ('#메로구이', 7),
#  ('#오늘뭐먹지', 7),
#  ('#송년회장소', 7),
#  ('#경천애인', 7),
#  ('#도쿄등심선릉점', 7),
#  ('#선릉족발', 7),
#  ('#선릉핫플', 7),
#  ('#이자카야', 7),
#  ('#오오티디', 7),
#  ('#아난티', 7),
#  ('#firebell', 7),
#  ('#판교역맛집', 7),
#  ('#초코쿠키', 7),
#  ('#신촌고기집', 7),
#  ('#삼산맛집', 7),
#  ('#크리스마스파티', 7),
#  ('#이달의아트', 7),
#  ('#자개네일', 7),
#  ('#선릉속는썹', 7),
#  ('#속눈썹수강', 7),
#  ('#이벤트네일', 7),
#  ('#왁싱수강', 7),
#  ('#브라질리언왁싱수강', 7),
#  ('#강남왁싱수강', 7),
#  ('#왁싱일대일수강', 7),
#  ('#강남속눈썹펌', 7),
#  ('#슈톨렌', 7),
#  ('#맛있다', 7),
#  ('#가족외식추천', 7),
#  ('#단체예약환영', 7),
#  ('#테이크아웃', 7),
#  ('#라윈', 7),
#  ('#카페맛집', 6),
#  ('#텐동', 6),
#  ('#저녁메뉴', 6),
#  ('#마들렌', 6),
#  ('#요리스타그램', 6),
#  ('#육아스타그램', 6),
#  ('#회사원', 6),
#  ('#망년회', 6),
#  ('#선릉조개구이', 6),
#  ('#조개구이무한리필', 6),
#  ('#야탑맛집', 6),
#  ('#김해카페', 6),
#  ('#속초맛집', 6),
#  ('#창원맛집', 6),
#  ('#성북구청맛집', 6),
#  ('#대한곱창', 6),
#  ('#이천맛집', 6),
#  ('#맥주', 6),
#  ('#마라중독', 6),
#  ('#연세대맛집', 6),
#  ('#민트라떼', 6),
#  ('#블링블링네일', 6),
#  ('#훌리오', 6),
#  ('#쉐프의멕시코요리', 6),
#  ('#훌리오배달', 6),
#  ('#훌리오배달전문점', 6),
#  ('#훌리오딜리버리', 6),
#  ('#강남술집', 6),
#  ('#떡볶이맛집', 6),
#  ('#속눈썹맛집', 6),
#  ('#선팔환영', 6),
#  ('#부산애터미', 6),
#  ('#청주애터미', 6),
#  ('#글로벌애터미', 6),
#  ('#샤브샤브', 6),
#  ('#가족모임장소', 6),
#  ('#곱창맛집', 6),
#  ('#파이어벨', 6),
#  ('#flowers', 6),
#  ('#flowershop', 6),
#  ('#dryflower', 6),
#  ('#dry', 6),
#  ('#동래맛집', 6),
#  ('#전포동카페', 6),
#  ('#선릉고기집', 6),
#  ('#레드와인', 6),
#  ('#양꼬치', 6),
#  ('#선릉미쓰양꼬치', 6),
#  ('#무한리필', 6),
#  ('#기세끼', 6),
#  ('#왕십리맛집', 6),
#  ('#반포맛집', 6),
#  ('#히비끼', 6),
#  ('#야마자끼', 6),
#  ('#우동', 6),
#  ('#메리크리스마스', 6),
#  ('#졸맛탱', 6),
#  ('#송리단길마카롱', 6),
#  ('#무광네일', 6),
#  ('#instagood', 6),
#  ('#옷스타그램', 6),
#  ('#해운대', 6),
#  ('#일상그램', 6),
#  ('#용호동반영구', 6),
#  ('#도쿄등심선릉', 6),
#  ('#burger', 6),
#  ('#햄버거', 6),
#  ('#선릉역데이트', 6),
#  ('#mukbang', 6),
#  ('#베이킹', 6),
#  ('#여수맛집', 6),
#  ('#yummy', 6),
#  ('#소공순대', 6),
#  ('#딸기타르트', 6),
#  ('#직장인스타그램', 6),
#  ('#산타마카롱', 6),
#  ('#눈사람마카롱', 6),
#  ('#건대왁싱', 6),
#  ('#선릉다크브라운', 6),
#  ('#육회', 6),
#  ('#푸드', 6),
#  ('#선릉역술집', 6),
#  ('#미대입시블랙', 6),
#  ('#닭발', 6),
#  ('#무뼈닭발', 6),
#  ('#용무있습니까대치점', 6),
#  ('#퓨전중식당', 6),
#  ('#쉐프의정육점', 6),
#  ('#트러플육회', 6),
#  ('#유화', 6),
#  ('#LaUne', 6),
#  ('#프랑스디저트', 6),
#  ('#케이크맛집', 6),
#  ('#홍차맛집', 6),
#  ('#삼성카페', 6),
#  ('#삼성데이트', 6),
#  ('#쌍룡갈비', 6),
#  ('#강남뚱카롱', 5),
#  ('#통밀', 5),
#  ('#시청맛집', 5),
#  ('#베이커리코리', 5),
#  ('#삼성중앙역마카롱', 5),
#  ('#삼성중앙역디저트', 5),
#  ('#삼성동디저트', 5),
#  ('#삼성동마카롱', 5),
#  ('#파운드', 5),
#  ('#오마카세', 5),
#  ('#연말파티', 5),
#  ('#우동맛집', 5),
#  ('#선릉눈썹문신', 5),
#  ('#감사합니다', 5),
#  ('#크리스마스이브', 5),
#  ('#얼스타그램', 5),
#  ('#겨울', 5),
#  ('#강남조개구이', 5),
#  ('#주말휴무', 5),
#  ('#흑당버블티', 5),
#  ('#부업추천', 5),
#  ('#규동', 5),
#  ('#강남속눈썹', 5),
#  ('#선릉곱창', 5),
#  ('#피슈마라홍탕신촌점', 5),
#  ('#신촌역맛집', 5),
#  ('#토요일정상오픈', 5),
#  ('#일요일정상오픈', 5),
#  ('#신촌역', 5),
#  ('#mbc스페셜', 5),
#  ('#유행음식', 5),
#  ('#mbc', 5),
#  ('#서강대맛집', 5),
#  ('#서강대역맛집', 5),
#  ('#신촌로터리맛집', 5),
#  ('#신촌로터리', 5),
#  ('#신촌역1번출구', 5),
#  ('#할로윈소품', 5),
#  ('#김치찌개', 5),
#  ('#선릉배달맛집', 5),
#  ('#마카롱케익', 5),
#  ('#주문', 5),
#  ('#원데이', 5),
#  ('#인스타그램', 5),
#  ('#친구', 5),
#  ('#레터링마카롱', 5),
#  ('#먹스타맞팔', 5),
#  ('#잘먹었습니다', 5),
#  ('#선릉스낵', 5),
#  ('#선릉역떡볶이', 5),
#  ('#대치동모임', 5),
#  ('#속눈썹연장', 5),
#  ('#인친환영', 5),
#  ('#고기집', 5),
#  ('#해운대핫플', 5),
#  ('#남포동네일', 5),
#  ('#해운대네일', 5),
#  ('#수요일', 5),
#  ('#로로피아나캐시미어', 5),
#  ('#로로피아나밍크', 5),
#  ('#보테가베네타코트', 5),
#  ('#디올코트', 5),
#  ('#삼겹살맛집', 5),
#  ('#와인모임', 5),
#  ('#와인스타그램', 5),
#  ('#오늘도', 5),
#  ('#강남점심맛집', 5),
#  ('#코엑스몰', 5),
#  ('#코엑스몰맛집', 5),
#  ('#선릉떡볶이맛집', 5),
#  ('#강남떡볶이배달', 5),
#  ('#숙성참치', 5),
#  ('#간장게장', 5),
#  ('#기세끼선릉', 5),
#  ('#선릉역이자카야', 5),
#  ('#역삼동이자카야', 5),
#  ('#명동피자', 5),
#  ('#명동맛집', 5),
#  ('#동대문맛집', 5),
#  ('#행복한오늘되세욤', 5),
#  ('#돈카츠', 5),
#  ('#한우맛집', 5),
#  ('#오마치슌', 5),
#  ('#사케', 5),
#  ('#술', 5),
#  ('#로로코트', 5),
#  ('#셀카그램', 5),
#  ('#꼬르소꼬모', 5),
#  ('#부산', 5),
#  ('#마린시티', 5),
#  ('#수입의류', 5),
#  ('#청주맛집', 5),
#  ('#파티룩', 5),
#  ('#여수반영구', 5),
#  ('#상남동네일', 5),
#  ('#판교현대백화점', 5),
#  ('#판교현대백화점맛집', 5),
#  ('#포스코맛집', 5),
#  ('#술안주', 5),
#  ('#밥스타그램', 5),
#  ('#연말회식장소', 5),
#  ('#강남구맛집', 5),
#  ('#인생맛집', 5),
#  ('#영등포맛집', 5),
#  ('#인계동맛집', 5),
#  ('#상남동맛집', 5),
#  ('#선정릉역맛집', 5),
#  ('#대전맛집', 5),
#  ('#선릉반영구', 5),
#  ('#서울연말모임장소', 5),
#  ('#바스버거', 5),
#  ('#데이트선물', 5),
#  ('#김해맛집', 5),
#  ('#고기맛집', 5),
#  ('#평양냉면', 5),
#  ('#델피늄', 5),
#  ('#거베라', 5),
#  ('#jmtgr', 5),
#  ('#돈까스', 5),
#  ('#참다랑어', 5),
#  ('#빨간마초닭발', 5),
#  ('#역삼점', 5),
#  ('#강남닭발', 5),
#  ('#빨간마초닭발X포차', 5),
#  ('#짬뽕지존', 5),
#  ('#암소서울', 5),
#  ('#취미', 5),
#  ('#한티역미술', 5),
#  ('#역삼속눈썹연장', 5),
#  ('#분위기좋은카페', 5),
#  ('#예쁜케이크', 5),
#  ('#예쁜디저트', 5),
#  ('#삼성디저트', 5),
#  ('#삼성동직장인', 5),
#  ('#양밥', 5),
#  ('#냠냠', 5),
#  ('#남양주맛집', 4),
#  ('#별내맛집', 4),
#  ('#강남구청맛집', 4),
#  ('#청계천', 4),
#  ('#마카롱스타그램', 4),
#  ('#seouleats', 4),
#  ('#likeforlikes', 4),
#  ('#육아소통', 4),
#  ('#간장새우', 4),
#  ('#진로', 4),
#  ('#냉삼', 4),
#  ('#냉동삼겹살', 4),
#  ('#서래향선릉점', 4),
#  ('#스테이크맛집', 4),
#  ('#뉴스킨', 4),
#  ('#아지트샵멘토', 4),
#  ('#남자눈썹', 4),
#  ('#전리단길맛집', 4),
#  ('#경남대술집', 4),
#  ('#물금반영구', 4),
#  ('#애드펌킨', 4),
#  ('#진해맛집', 4),
#  ('#텐동맛집', 4),
#  ('#아침식사', 4),
#  ('#붙임머리', 4),
#  ('#순대국밥', 4),
#  ('#foodpics', 4),
#  ('#해장', 4),
#  ('#대구피부관리', 4),
#  ('#삼성중앙역', 4),
#  ('#마블링', 4),
#  ('#대파양곱창', 4),
#  ('#한우등심', 4),
#  ('#할로윈선물', 4),
#  ('#강남다쿠아즈', 4),
#  ('#삼성동배달맛집', 4),
#  ('#선릉배달', 4),
#  ('#삼성역배달맛집', 4),
#  ('#도시락배달', 4),
#  ('#파히타', 4),
#  ('#퀘사디아', 4),
#  ('#봉남치킨', 4),
#  ('#주문제작', 4),
#  ('#원데이클래스문의', 4),
#  ('#육아맘', 4),
#  ('#초밥', 4),
#  ('#선릉역맛집추천', 4),
#  ('#삼성동고기집', 4),
#  ('#대치동맛집추천', 4),
#  ('#화사곱창', 4),
#  ('#막창', 4),
#  ('#서울여행', 4),
#  ('#델라마노', 4),
#  ('#스피크이지마노', 4),
#  ('#시가바', 4),
#  ('#시가', 4),
#  ('#시가라운지', 4),
#  ('#다비도프', 4),
#  ('#cigarbar', 4),
#  ('#cigarlounge', 4),
#  ('#가을꽃다발', 4),
#  ('#서면네일', 4),
#  ('#영도맛집', 4),
#  ('#기장카페추천', 4),
#  ('#부산근교데이트', 4),
#  ('#부산데이트', 4),
#  ('#송도카페', 4),
#  ('#부산카페투어', 4),
#  ('#수성구맛집', 4),
#  ('#블랙랩', 4),
#  ('#선릉역삼겹살', 4),
#  ('#선릉삼겹살', 4),
#  ('#주말', 4),
#  ('#로로피아나로퍼', 4),
#  ('#오픈', 4),
#  ('#한티', 4),
#  ('#wine', 4),
#  ('#레몬티', 4),
#  ('#담소소사골순대육개장', 4),
#  ('#담소소사골순대역삼3호점', 4),
#  ('#담소소사골순대상록회관점', 4),
#  ('#핸드포크타투', 4),
#  ('#강남타투', 4),
#  ('#역삼타투', 4),
#  ...]
